# %%
# Python code for Random Walk in One Dimension of the X, Y Axis.
# My method as described in my repo from 2022: p19pago/probability-2022
# Lab 7 out of total 10 we did in class, as taken place on Tuesday April 12th 2022

# %%
# solution without decimals

# %%
# Code
# Import functions as to be used during the code
# Functions that will be used: random (for random numbers), numpy (for mathematical functions/symbols)
# and matplotlib to implement the final chart and position of the walker.
# Initialization

# %%
import random # random numbers
import numpy as np # mathematical functions and symbols each
import matplotlib.pyplot as plt # diagram/graph plotting package

# %%
# we first import the three (3) basic libraries as described in the comments on the first 8 lines of the code
# either way we should have imported the "time" library, but it does not count in our method
# because it measures the number of seconds since January 1st 1970.
# but we will use arrays to declare our final points and positions (using np)

# %%
# let's get to the main point of the code and what it actually needs.
# variable declaration

# %%
# in Python you cannot declare a variable without assigning its value, so we are going to use values for each variable
# variables that will be of use on our method are:

# %%
# generic variables

# %%
#       x (a random variable)
#       rw (an array determining the amount of walks in one dimension)

# %%
x = 0 # x must be initialized to 0
rw = np.zeros(1000) # a 1 dimensional array consisting of zeros at the beginning.
# It determines the amount of walks in one dimension.

# %%
# other variables
# first walkers

# %%
#       p1 (position for the first walker as it is moving across the axis)
#       s1 (registered position for the first walker as shown in the chart)

# %%
p1 = 0 # position for the first walker must be initialized to 0
s1 = [0] # registered position for the first walker, also must be initialized to 0

# %%
# no heads or tails will be of need in this example

# %%
# IMPORTANT: before we move into the main part of the code, we should alter the values of the array
# so instead of zeros it should be integers from 0 to 1000

# %%
rw = np.arange(0, 1000)

# %%
# main part of the code

# %%
# using a for-loop to determine time points and positions as the walker moves around.

# %%
for i in range (1, 1000): # first we begin with 1000 rolls

    x = random.randint(0,9)
    print("Random number result is: ", x)

    # two simple if-structures to determine if the walker should move up or down

    # if-structure if x is greater than 5
    
    if (x>5):
        p1 = x + 1
        s1.append (rw[p1])
        
    # if-structure if x is smaller than 5
     
    if (x<5):
        p1 = x - 1
        s1.append (rw[p1])
# Out:
# Random number result is:  0
# Random number result is:  0
# Random number result is:  9
# Random number result is:  5
# Random number result is:  1
# Random number result is:  0
# Random number result is:  3
# Random number result is:  1
# Random number result is:  5
# Random number result is:  7
# Random number result is:  6
# Random number result is:  4
# Random number result is:  2
# Random number result is:  1
# Random number result is:  1
# Random number result is:  3
# Random number result is:  3
# Random number result is:  5
# Random number result is:  0
# Random number result is:  3
# Random number result is:  5
# Random number result is:  2
# Random number result is:  0
# Random number result is:  4
# Random number result is:  0
# Random number result is:  3
# Random number result is:  7
# Random number result is:  2
# Random number result is:  0
# Random number result is:  4
# Random number result is:  8
# Random number result is:  2
# Random number result is:  2
# Random number result is:  1
# Random number result is:  7
# Random number result is:  1
# Random number result is:  1
# Random number result is:  8
# Random number result is:  6
# Random number result is:  1
# Random number result is:  8
# Random number result is:  3
# Random number result is:  3
# Random number result is:  8
# Random number result is:  9
# Random number result is:  8
# Random number result is:  1
# Random number result is:  5
# Random number result is:  1
# Random number result is:  2
# Random number result is:  0
# Random number result is:  9
# Random number result is:  4
# Random number result is:  1
# Random number result is:  2
# Random number result is:  9
# Random number result is:  3
# Random number result is:  4
# Random number result is:  0
# Random number result is:  6
# Random number result is:  0
# Random number result is:  9
# Random number result is:  2
# Random number result is:  1
# Random number result is:  4
# Random number result is:  4
# Random number result is:  3
# Random number result is:  1
# Random number result is:  6
# Random number result is:  2
# Random number result is:  7
# Random number result is:  5
# Random number result is:  7
# Random number result is:  0
# Random number result is:  5
# Random number result is:  3
# Random number result is:  1
# Random number result is:  2
# Random number result is:  4
# Random number result is:  9
# Random number result is:  5
# Random number result is:  8
# Random number result is:  6
# Random number result is:  9
# Random number result is:  2
# Random number result is:  4
# Random number result is:  4
# Random number result is:  7
# Random number result is:  1
# Random number result is:  8
# Random number result is:  0
# Random number result is:  2
# Random number result is:  7
# Random number result is:  2
# Random number result is:  1
# Random number result is:  0
# Random number result is:  4
# Random number result is:  5
# Random number result is:  3
# Random number result is:  2
# Random number result is:  3
# Random number result is:  9
# Random number result is:  5
# Random number result is:  0
# Random number result is:  7
# Random number result is:  5
# Random number result is:  8
# Random number result is:  6
# Random number result is:  5
# Random number result is:  4
# Random number result is:  1
# Random number result is:  9
# Random number result is:  7
# Random number result is:  2
# Random number result is:  4
# Random number result is:  9
# Random number result is:  4
# Random number result is:  1
# Random number result is:  3
# Random number result is:  5
# Random number result is:  6
# Random number result is:  3
# Random number result is:  2
# Random number result is:  6
# Random number result is:  4
# Random number result is:  0
# Random number result is:  1
# Random number result is:  7
# Random number result is:  9
# Random number result is:  8
# Random number result is:  3
# Random number result is:  0
# Random number result is:  8
# Random number result is:  4
# Random number result is:  9
# Random number result is:  4
# Random number result is:  6
# Random number result is:  3
# Random number result is:  3
# Random number result is:  5
# Random number result is:  3
# Random number result is:  8
# Random number result is:  6
# Random number result is:  2
# Random number result is:  8
# Random number result is:  2
# Random number result is:  4
# Random number result is:  0
# Random number result is:  2
# Random number result is:  3
# Random number result is:  7
# Random number result is:  0
# Random number result is:  8
# Random number result is:  0
# Random number result is:  4
# Random number result is:  7
# Random number result is:  5
# Random number result is:  5
# Random number result is:  6
# Random number result is:  1
# Random number result is:  9
# Random number result is:  2
# Random number result is:  6
# Random number result is:  7
# Random number result is:  8
# Random number result is:  9
# Random number result is:  1
# Random number result is:  8
# Random number result is:  3
# Random number result is:  8
# Random number result is:  6
# Random number result is:  1
# Random number result is:  8
# Random number result is:  9
# Random number result is:  7
# Random number result is:  2
# Random number result is:  5
# Random number result is:  8
# Random number result is:  8
# Random number result is:  8
# Random number result is:  6
# Random number result is:  3
# Random number result is:  1
# Random number result is:  0
# Random number result is:  6
# Random number result is:  3
# Random number result is:  6
# Random number result is:  9
# Random number result is:  5
# Random number result is:  8
# Random number result is:  7
# Random number result is:  2
# Random number result is:  4
# Random number result is:  7
# Random number result is:  3
# Random number result is:  6
# Random number result is:  9
# Random number result is:  4
# Random number result is:  1
# Random number result is:  9
# Random number result is:  8
# Random number result is:  0
# Random number result is:  9
# Random number result is:  3
# Random number result is:  5
# Random number result is:  3
# Random number result is:  3
# Random number result is:  4
# Random number result is:  7
# Random number result is:  3
# Random number result is:  3
# Random number result is:  0
# Random number result is:  4
# Random number result is:  2
# Random number result is:  1
# Random number result is:  8
# Random number result is:  4
# Random number result is:  7
# Random number result is:  9
# Random number result is:  8
# Random number result is:  7
# Random number result is:  3
# Random number result is:  7
# Random number result is:  6
# Random number result is:  3
# Random number result is:  2
# Random number result is:  5
# Random number result is:  5
# Random number result is:  3
# Random number result is:  9
# Random number result is:  1
# Random number result is:  7
# Random number result is:  0
# Random number result is:  6
# Random number result is:  9
# Random number result is:  6
# Random number result is:  0
# Random number result is:  0
# Random number result is:  4
# Random number result is:  6
# Random number result is:  7
# Random number result is:  3
# Random number result is:  9
# Random number result is:  8
# Random number result is:  4
# Random number result is:  9
# Random number result is:  3
# Random number result is:  4
# Random number result is:  2
# Random number result is:  3
# Random number result is:  4
# Random number result is:  3
# Random number result is:  1
# Random number result is:  4
# Random number result is:  6
# Random number result is:  3
# Random number result is:  7
# Random number result is:  6
# Random number result is:  7
# Random number result is:  8
# Random number result is:  0
# Random number result is:  7
# Random number result is:  4
# Random number result is:  9
# Random number result is:  0
# Random number result is:  8
# Random number result is:  1
# Random number result is:  5
# Random number result is:  2
# Random number result is:  2
# Random number result is:  8
# Random number result is:  7
# Random number result is:  9
# Random number result is:  5
# Random number result is:  0
# Random number result is:  9
# Random number result is:  5
# Random number result is:  2
# Random number result is:  7
# Random number result is:  9
# Random number result is:  0
# Random number result is:  0
# Random number result is:  7
# Random number result is:  1
# Random number result is:  0
# Random number result is:  9
# Random number result is:  5
# Random number result is:  0
# Random number result is:  9
# Random number result is:  4
# Random number result is:  9
# Random number result is:  6
# Random number result is:  5
# Random number result is:  2
# Random number result is:  9
# Random number result is:  8
# Random number result is:  9
# Random number result is:  3
# Random number result is:  3
# Random number result is:  0
# Random number result is:  7
# Random number result is:  8
# Random number result is:  6
# Random number result is:  4
# Random number result is:  3
# Random number result is:  8
# Random number result is:  9
# Random number result is:  9
# Random number result is:  0
# Random number result is:  2
# Random number result is:  5
# Random number result is:  3
# Random number result is:  8
# Random number result is:  2
# Random number result is:  5
# Random number result is:  5
# Random number result is:  4
# Random number result is:  9
# Random number result is:  5
# Random number result is:  4
# Random number result is:  7
# Random number result is:  0
# Random number result is:  3
# Random number result is:  9
# Random number result is:  0
# Random number result is:  9
# Random number result is:  9
# Random number result is:  3
# Random number result is:  0
# Random number result is:  4
# Random number result is:  8
# Random number result is:  6
# Random number result is:  8
# Random number result is:  8
# Random number result is:  2
# Random number result is:  9
# Random number result is:  0
# Random number result is:  9
# Random number result is:  5
# Random number result is:  9
# Random number result is:  7
# Random number result is:  0
# Random number result is:  4
# Random number result is:  3
# Random number result is:  6
# Random number result is:  2
# Random number result is:  0
# Random number result is:  6
# Random number result is:  1
# Random number result is:  9
# Random number result is:  8
# Random number result is:  8
# Random number result is:  7
# Random number result is:  5
# Random number result is:  0
# Random number result is:  8
# Random number result is:  2
# Random number result is:  5
# Random number result is:  9
# Random number result is:  2
# Random number result is:  1
# Random number result is:  1
# Random number result is:  0
# Random number result is:  3
# Random number result is:  4
# Random number result is:  2
# Random number result is:  9
# Random number result is:  1
# Random number result is:  0
# Random number result is:  8
# Random number result is:  6
# Random number result is:  2
# Random number result is:  9
# Random number result is:  0
# Random number result is:  5
# Random number result is:  4
# Random number result is:  9
# Random number result is:  8
# Random number result is:  6
# Random number result is:  1
# Random number result is:  9
# Random number result is:  7
# Random number result is:  5
# Random number result is:  6
# Random number result is:  6
# Random number result is:  4
# Random number result is:  8
# Random number result is:  4
# Random number result is:  6
# Random number result is:  3
# Random number result is:  8
# Random number result is:  2
# Random number result is:  6
# Random number result is:  4
# Random number result is:  8
# Random number result is:  3
# Random number result is:  9
# Random number result is:  7
# Random number result is:  1
# Random number result is:  8
# Random number result is:  8
# Random number result is:  3
# Random number result is:  2
# Random number result is:  6
# Random number result is:  1
# Random number result is:  3
# Random number result is:  7
# Random number result is:  6
# Random number result is:  2
# Random number result is:  4
# Random number result is:  0
# Random number result is:  6
# Random number result is:  4
# Random number result is:  2
# Random number result is:  8
# Random number result is:  1
# Random number result is:  7
# Random number result is:  4
# Random number result is:  5
# Random number result is:  3
# Random number result is:  0
# Random number result is:  6
# Random number result is:  4
# Random number result is:  4
# Random number result is:  8
# Random number result is:  2
# Random number result is:  2
# Random number result is:  1
# Random number result is:  3
# Random number result is:  3
# Random number result is:  5
# Random number result is:  1
# Random number result is:  9
# Random number result is:  6
# Random number result is:  9
# Random number result is:  7
# Random number result is:  7
# Random number result is:  0
# Random number result is:  0
# Random number result is:  6
# Random number result is:  2
# Random number result is:  8
# Random number result is:  8
# Random number result is:  3
# Random number result is:  5
# Random number result is:  1
# Random number result is:  5
# Random number result is:  5
# Random number result is:  7
# Random number result is:  8
# Random number result is:  8
# Random number result is:  8
# Random number result is:  6
# Random number result is:  7
# Random number result is:  8
# Random number result is:  7
# Random number result is:  4
# Random number result is:  2
# Random number result is:  2
# Random number result is:  8
# Random number result is:  4
# Random number result is:  8
# Random number result is:  6
# Random number result is:  9
# Random number result is:  7
# Random number result is:  3
# Random number result is:  6
# Random number result is:  7
# Random number result is:  9
# Random number result is:  2
# Random number result is:  0
# Random number result is:  8
# Random number result is:  6
# Random number result is:  0
# Random number result is:  0
# Random number result is:  5
# Random number result is:  5
# Random number result is:  7
# Random number result is:  6
# Random number result is:  7
# Random number result is:  3
# Random number result is:  2
# Random number result is:  9
# Random number result is:  7
# Random number result is:  8
# Random number result is:  3
# Random number result is:  5
# Random number result is:  5
# Random number result is:  6
# Random number result is:  5
# Random number result is:  6
# Random number result is:  1
# Random number result is:  8
# Random number result is:  1
# Random number result is:  9
# Random number result is:  8
# Random number result is:  6
# Random number result is:  3
# Random number result is:  9
# Random number result is:  3
# Random number result is:  4
# Random number result is:  3
# Random number result is:  8
# Random number result is:  3
# Random number result is:  3
# Random number result is:  1
# Random number result is:  9
# Random number result is:  0
# Random number result is:  4
# Random number result is:  4
# Random number result is:  6
# Random number result is:  2
# Random number result is:  0
# Random number result is:  0
# Random number result is:  8
# Random number result is:  2
# Random number result is:  3
# Random number result is:  6
# Random number result is:  7
# Random number result is:  0
# Random number result is:  6
# Random number result is:  4
# Random number result is:  0
# Random number result is:  0
# Random number result is:  2
# Random number result is:  9
# Random number result is:  1
# Random number result is:  3
# Random number result is:  6
# Random number result is:  1
# Random number result is:  1
# Random number result is:  7
# Random number result is:  2
# Random number result is:  2
# Random number result is:  9
# Random number result is:  8
# Random number result is:  6
# Random number result is:  0
# Random number result is:  1
# Random number result is:  6
# Random number result is:  1
# Random number result is:  4
# Random number result is:  7
# Random number result is:  7
# Random number result is:  0
# Random number result is:  9
# Random number result is:  1
# Random number result is:  4
# Random number result is:  9
# Random number result is:  6
# Random number result is:  3
# Random number result is:  7
# Random number result is:  2
# Random number result is:  4
# Random number result is:  0
# Random number result is:  1
# Random number result is:  7
# Random number result is:  8
# Random number result is:  4
# Random number result is:  2
# Random number result is:  8
# Random number result is:  9
# Random number result is:  0
# Random number result is:  8
# Random number result is:  7
# Random number result is:  7
# Random number result is:  4
# Random number result is:  5
# Random number result is:  1
# Random number result is:  7
# Random number result is:  9
# Random number result is:  1
# Random number result is:  3
# Random number result is:  0
# Random number result is:  1
# Random number result is:  0
# Random number result is:  5
# Random number result is:  0
# Random number result is:  9
# Random number result is:  4
# Random number result is:  9
# Random number result is:  4
# Random number result is:  3
# Random number result is:  0
# Random number result is:  9
# Random number result is:  2
# Random number result is:  1
# Random number result is:  4
# Random number result is:  2
# Random number result is:  7
# Random number result is:  2
# Random number result is:  6
# Random number result is:  5
# Random number result is:  4
# Random number result is:  1
# Random number result is:  1
# Random number result is:  3
# Random number result is:  5
# Random number result is:  2
# Random number result is:  5
# Random number result is:  9
# Random number result is:  5
# Random number result is:  0
# Random number result is:  1
# Random number result is:  2
# Random number result is:  6
# Random number result is:  0
# Random number result is:  7
# Random number result is:  3
# Random number result is:  1
# Random number result is:  6
# Random number result is:  0
# Random number result is:  6
# Random number result is:  9
# Random number result is:  5
# Random number result is:  8
# Random number result is:  9
# Random number result is:  3
# Random number result is:  4
# Random number result is:  4
# Random number result is:  2
# Random number result is:  9
# Random number result is:  0
# Random number result is:  9
# Random number result is:  8
# Random number result is:  3
# Random number result is:  8
# Random number result is:  0
# Random number result is:  8
# Random number result is:  3
# Random number result is:  1
# Random number result is:  3
# Random number result is:  0
# Random number result is:  5
# Random number result is:  5
# Random number result is:  9
# Random number result is:  9
# Random number result is:  9
# Random number result is:  4
# Random number result is:  5
# Random number result is:  7
# Random number result is:  1
# Random number result is:  4
# Random number result is:  9
# Random number result is:  9
# Random number result is:  1
# Random number result is:  8
# Random number result is:  3
# Random number result is:  1
# Random number result is:  1
# Random number result is:  2
# Random number result is:  9
# Random number result is:  0
# Random number result is:  0
# Random number result is:  8
# Random number result is:  4
# Random number result is:  8
# Random number result is:  7
# Random number result is:  5
# Random number result is:  2
# Random number result is:  4
# Random number result is:  1
# Random number result is:  6
# Random number result is:  6
# Random number result is:  5
# Random number result is:  9
# Random number result is:  4
# Random number result is:  0
# Random number result is:  9
# Random number result is:  0
# Random number result is:  8
# Random number result is:  2
# Random number result is:  3
# Random number result is:  4
# Random number result is:  7
# Random number result is:  8
# Random number result is:  6
# Random number result is:  4
# Random number result is:  3
# Random number result is:  0
# Random number result is:  8
# Random number result is:  3
# Random number result is:  7
# Random number result is:  9
# Random number result is:  9
# Random number result is:  9
# Random number result is:  9
# Random number result is:  2
# Random number result is:  8
# Random number result is:  4
# Random number result is:  6
# Random number result is:  6
# Random number result is:  8
# Random number result is:  2
# Random number result is:  7
# Random number result is:  6
# Random number result is:  8
# Random number result is:  3
# Random number result is:  8
# Random number result is:  7
# Random number result is:  5
# Random number result is:  4
# Random number result is:  7
# Random number result is:  6
# Random number result is:  5
# Random number result is:  7
# Random number result is:  5
# Random number result is:  4
# Random number result is:  1
# Random number result is:  1
# Random number result is:  7
# Random number result is:  7
# Random number result is:  0
# Random number result is:  6
# Random number result is:  6
# Random number result is:  0
# Random number result is:  2
# Random number result is:  2
# Random number result is:  4
# Random number result is:  9
# Random number result is:  9
# Random number result is:  3
# Random number result is:  4
# Random number result is:  2
# Random number result is:  4
# Random number result is:  4
# Random number result is:  4
# Random number result is:  3
# Random number result is:  7
# Random number result is:  1
# Random number result is:  2
# Random number result is:  9
# Random number result is:  7
# Random number result is:  8
# Random number result is:  6
# Random number result is:  5
# Random number result is:  0
# Random number result is:  9
# Random number result is:  8
# Random number result is:  5
# Random number result is:  0
# Random number result is:  0
# Random number result is:  9
# Random number result is:  3
# Random number result is:  7
# Random number result is:  3
# Random number result is:  5
# Random number result is:  9
# Random number result is:  0
# Random number result is:  6
# Random number result is:  7
# Random number result is:  7
# Random number result is:  3
# Random number result is:  6
# Random number result is:  9
# Random number result is:  9
# Random number result is:  3
# Random number result is:  7
# Random number result is:  8
# Random number result is:  8
# Random number result is:  1
# Random number result is:  0
# Random number result is:  4
# Random number result is:  9
# Random number result is:  3
# Random number result is:  4
# Random number result is:  0
# Random number result is:  9
# Random number result is:  7
# Random number result is:  4
# Random number result is:  2
# Random number result is:  3
# Random number result is:  6
# Random number result is:  2
# Random number result is:  7
# Random number result is:  9
# Random number result is:  9
# Random number result is:  7
# Random number result is:  4
# Random number result is:  2
# Random number result is:  2
# Random number result is:  7
# Random number result is:  2
# Random number result is:  1
# Random number result is:  3
# Random number result is:  2
# Random number result is:  0
# Random number result is:  3
# Random number result is:  0
# Random number result is:  5
# Random number result is:  9
# Random number result is:  8
# Random number result is:  2
# Random number result is:  3
# Random number result is:  2
# Random number result is:  0
# Random number result is:  2
# Random number result is:  4
# Random number result is:  1
# Random number result is:  2
# Random number result is:  1
# Random number result is:  3
# Random number result is:  8
# Random number result is:  3
# Random number result is:  5
# Random number result is:  0
# Random number result is:  9
# Random number result is:  2
# Random number result is:  3
# Random number result is:  0
# Random number result is:  4
# Random number result is:  3
# Random number result is:  5
# Random number result is:  9
# Random number result is:  6
# Random number result is:  4
# Random number result is:  4
# Random number result is:  1
# Random number result is:  6
# Random number result is:  0
# Random number result is:  3
# Random number result is:  2
# Random number result is:  5
# Random number result is:  9
# Random number result is:  6
# Random number result is:  8
# Random number result is:  8
# Random number result is:  1
# Random number result is:  2
# Random number result is:  6
# Random number result is:  9
# Random number result is:  7
# Random number result is:  2
# Random number result is:  7
# Random number result is:  6
# Random number result is:  2
# Random number result is:  4
# Random number result is:  6
# Random number result is:  2
# Random number result is:  6
# Random number result is:  7
# Random number result is:  5
# Random number result is:  1
# Random number result is:  3
# Random number result is:  3
# Random number result is:  0
# Random number result is:  6
# Random number result is:  9
# Random number result is:  9
# Random number result is:  2
# Random number result is:  3
# Random number result is:  8
# Random number result is:  5
# Random number result is:  2
# Random number result is:  3
# Random number result is:  8
# Random number result is:  8
# Random number result is:  8
# Random number result is:  4
# Random number result is:  3
# Random number result is:  8
# Random number result is:  4
# Random number result is:  2
# Random number result is:  6
# Random number result is:  9
# Random number result is:  8
# Random number result is:  7
# Random number result is:  9
# Random number result is:  8
# Random number result is:  3
# Random number result is:  7
# Random number result is:  1
# Random number result is:  7
# Random number result is:  8
# Random number result is:  5
# Random number result is:  5
# Random number result is:  6
# Random number result is:  9
# Random number result is:  0
# Random number result is:  6
# Random number result is:  7
# Random number result is:  2
# Random number result is:  2
# Random number result is:  0
# Random number result is:  6
# Random number result is:  0
# Random number result is:  5
# Random number result is:  6
# Random number result is:  2
# Random number result is:  1
# Random number result is:  9
# Random number result is:  2
# Random number result is:  7
# Random number result is:  2
# Random number result is:  4
# Random number result is:  9
# Random number result is:  8
# Random number result is:  4
# Random number result is:  0
# Random number result is:  1
# Random number result is:  1
# Random number result is:  6
# Random number result is:  0
# Random number result is:  2
# Random number result is:  6
# Random number result is:  0
# Random number result is:  1
# Random number result is:  7
# Random number result is:  9
# Random number result is:  7
# Random number result is:  0
# Random number result is:  7
# Random number result is:  4
# Random number result is:  5
# Random number result is:  6
# Random number result is:  7
# Random number result is:  5
# Random number result is:  9
# Random number result is:  0
# Random number result is:  4
# Random number result is:  8
# Random number result is:  1
# Random number result is:  8
# Random number result is:  0
# Random number result is:  9
# Random number result is:  1
# Random number result is:  4
# Random number result is:  4
# Random number result is:  9
# Random number result is:  3
# Random number result is:  5
# Random number result is:  7
# Random number result is:  4
# Random number result is:  3
# Random number result is:  9
# Random number result is:  7
# Random number result is:  8
# Random number result is:  5
# Random number result is:  6
# Random number result is:  7
# Random number result is:  8
# Random number result is:  3
# Random number result is:  0
# Random number result is:  9
# Random number result is:  7
# Random number result is:  4
# Random number result is:  3
# Random number result is:  6
# Random number result is:  1
# Random number result is:  0
# Random number result is:  1
# Random number result is:  9
# Random number result is:  0
# Random number result is:  3
# Random number result is:  6
# Random number result is:  2
# Random number result is:  9
# Random number result is:  4
# Random number result is:  3
# Random number result is:  6
# Random number result is:  5
# Random number result is:  6
# Random number result is:  7
# Random number result is:  4
# Random number result is:  9
# Random number result is:  2
# Random number result is:  0
# Random number result is:  1
# Random number result is:  6
# Random number result is:  0
# Random number result is:  2
# Random number result is:  5
# Random number result is:  2
# Random number result is:  7
# Random number result is:  4
# Random number result is:  4
# Random number result is:  9
# Random number result is:  7
# Random number result is:  8
# Random number result is:  6
# Random number result is:  8
# Random number result is:  5
# Random number result is:  1
# Random number result is:  1
# Random number result is:  5
# Random number result is:  8
# Random number result is:  1
# Random number result is:  4
# Random number result is:  2
# Random number result is:  1
# Random number result is:  3
# Random number result is:  2
# Random number result is:  4
# Random number result is:  5
# Random number result is:  8
# Random number result is:  9
# Random number result is:  1
# Random number result is:  0
# Random number result is:  0

# %%
print("Registered position for the first walker is: ", s1) 
print ("Final position for the first walker is:", p1)
# Out:
# Registered position for the first walker is:  [0, 999, 999, 10, 0, 999, 2, 0, 8, 7, 3, 1, 0, 0, 2, 2, 999, 2, 1, 999, 3, 999, 2, 8, 1, 999, 3, 9, 1, 1, 0, 8, 0, 0, 9, 7, 0, 9, 2, 2, 9, 10, 9, 0, 0, 1, 999, 10, 3, 0, 1, 10, 2, 3, 999, 7, 999, 10, 1, 0, 3, 3, 2, 0, 7, 1, 8, 8, 999, 2, 0, 1, 3, 10, 9, 7, 10, 1, 3, 3, 8, 0, 9, 999, 1, 8, 1, 0, 999, 3, 2, 1, 2, 10, 999, 8, 9, 7, 3, 0, 10, 8, 1, 3, 10, 3, 0, 2, 7, 2, 1, 7, 3, 999, 0, 8, 10, 9, 2, 999, 9, 3, 10, 3, 7, 2, 2, 2, 9, 7, 1, 9, 1, 3, 999, 1, 2, 8, 999, 9, 999, 3, 8, 7, 0, 10, 1, 7, 8, 9, 10, 0, 9, 2, 9, 7, 0, 9, 10, 8, 1, 9, 9, 9, 7, 2, 0, 999, 7, 2, 7, 10, 9, 8, 1, 3, 8, 2, 7, 10, 3, 0, 10, 9, 999, 10, 2, 2, 2, 3, 8, 2, 2, 999, 3, 1, 0, 9, 3, 8, 10, 9, 8, 2, 8, 7, 2, 1, 2, 10, 0, 8, 999, 7, 10, 7, 999, 999, 3, 7, 8, 2, 10, 9, 3, 10, 2, 3, 1, 2, 3, 2, 0, 3, 7, 2, 8, 7, 8, 9, 999, 8, 3, 10, 999, 9, 0, 1, 1, 9, 8, 10, 999, 10, 1, 8, 10, 999, 999, 8, 0, 999, 10, 999, 10, 3, 10, 7, 1, 10, 9, 10, 2, 2, 999, 8, 9, 7, 3, 2, 9, 10, 10, 999, 1, 2, 9, 1, 3, 10, 3, 8, 999, 2, 10, 999, 10, 10, 2, 999, 3, 9, 7, 9, 9, 1, 10, 999, 10, 10, 8, 999, 3, 2, 7, 1, 999, 7, 0, 10, 9, 9, 8, 999, 9, 1, 10, 1, 0, 0, 999, 2, 3, 1, 10, 0, 999, 9, 7, 1, 10, 999, 3, 10, 9, 7, 0, 10, 8, 7, 7, 3, 9, 3, 7, 2, 9, 1, 7, 3, 9, 2, 10, 8, 0, 9, 9, 2, 1, 7, 0, 2, 8, 7, 1, 3, 999, 7, 3, 1, 9, 0, 8, 3, 2, 999, 7, 3, 3, 9, 1, 1, 0, 2, 2, 0, 10, 7, 10, 8, 8, 999, 999, 7, 1, 9, 9, 2, 0, 8, 9, 9, 9, 7, 8, 9, 8, 3, 1, 1, 9, 3, 9, 7, 10, 8, 2, 7, 8, 10, 1, 999, 9, 7, 999, 999, 8, 7, 8, 2, 1, 10, 8, 9, 2, 7, 7, 0, 9, 0, 10, 9, 7, 2, 10, 2, 3, 2, 9, 2, 2, 0, 10, 999, 3, 3, 7, 1, 999, 999, 9, 1, 2, 7, 8, 999, 7, 3, 999, 999, 1, 10, 0, 2, 7, 0, 0, 8, 1, 1, 10, 9, 7, 999, 0, 7, 0, 3, 8, 8, 999, 10, 0, 3, 10, 7, 2, 8, 1, 3, 999, 0, 8, 9, 3, 1, 9, 10, 999, 9, 8, 8, 3, 0, 8, 10, 0, 2, 999, 0, 999, 999, 10, 3, 10, 3, 2, 999, 10, 1, 0, 3, 1, 8, 1, 7, 3, 0, 0, 2, 1, 10, 999, 0, 1, 7, 999, 8, 2, 0, 7, 999, 7, 10, 9, 10, 2, 3, 3, 1, 10, 999, 10, 9, 2, 9, 999, 9, 2, 0, 2, 999, 10, 10, 10, 3, 8, 0, 3, 10, 10, 0, 9, 2, 0, 0, 1, 10, 999, 999, 9, 3, 9, 8, 1, 3, 0, 7, 7, 10, 3, 999, 10, 999, 9, 1, 2, 3, 8, 9, 7, 3, 2, 999, 9, 2, 8, 10, 10, 10, 10, 1, 9, 3, 7, 7, 9, 1, 8, 7, 9, 2, 9, 8, 3, 8, 7, 8, 3, 0, 0, 8, 8, 999, 7, 7, 999, 1, 1, 3, 10, 10, 2, 3, 1, 3, 3, 3, 2, 8, 0, 1, 10, 8, 9, 7, 999, 10, 9, 999, 999, 10, 2, 8, 2, 10, 999, 7, 8, 8, 2, 7, 10, 10, 2, 8, 9, 9, 0, 999, 3, 10, 2, 3, 999, 10, 8, 3, 1, 2, 7, 1, 8, 10, 10, 8, 3, 1, 1, 8, 1, 0, 2, 1, 999, 2, 999, 10, 9, 1, 2, 1, 999, 1, 3, 0, 1, 0, 2, 9, 2, 999, 10, 1, 2, 999, 3, 2, 10, 7, 3, 3, 0, 7, 999, 2, 1, 10, 7, 9, 9, 0, 1, 7, 10, 8, 1, 8, 7, 1, 3, 7, 1, 7, 8, 0, 2, 2, 999, 7, 10, 10, 1, 2, 9, 1, 2, 9, 9, 9, 3, 2, 9, 3, 1, 7, 10, 9, 8, 10, 9, 2, 8, 0, 8, 9, 7, 10, 999, 7, 8, 1, 1, 999, 7, 999, 7, 1, 0, 10, 1, 8, 1, 3, 10, 9, 3, 999, 0, 0, 7, 999, 1, 7, 999, 0, 8, 10, 8, 999, 8, 3, 7, 8, 10, 999, 3, 9, 0, 9, 999, 10, 0, 3, 3, 10, 2, 8, 3, 2, 10, 8, 9, 7, 8, 9, 2, 999, 10, 8, 3, 2, 7, 0, 999, 0, 10, 999, 2, 7, 1, 10, 3, 2, 7, 7, 8, 3, 10, 1, 999, 0, 7, 999, 1, 1, 8, 3, 3, 10, 8, 9, 7, 9, 0, 0, 9, 0, 3, 1, 0, 2, 1, 3, 9, 10, 0, 999, 999]
# Final position for the first walker is: -1

# %%
# plotting down the graph of the random walk in 1 dimension
# using pyplot

# %%
plt.plot(s1)
plt.show()
